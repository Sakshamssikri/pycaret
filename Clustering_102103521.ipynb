# %%
# !pip install pycaret &> /dev/null
print ("Pycaret installed sucessfully!!")
# Out:
# Pycaret installed sucessfully!!

# %%
from pycaret.utils import version
version()
# Out:
# '3.2.0'

# %%
from pycaret.datasets import get_data
dataSets = get_data('index')
# Out:
#                              Dataset    Data Types  \
# 0                            anomaly  Multivariate
# 1                             france  Multivariate
# 2                            germany  Multivariate
# 3                               bank  Multivariate
# 4                              blood  Multivariate
# 5                             cancer  Multivariate
# 6                             credit  Multivariate
# 7                           diabetes  Multivariate
# 8                    electrical_grid  Multivariate
# 9                           employee  Multivariate
# 10                             heart  Multivariate
# 11                     heart_disease  Multivariate
# 12                         hepatitis  Multivariate
# 13                            income  Multivariate
# 14                             juice  Multivariate
# 15                               nba  Multivariate
# 16                              wine  Multivariate
# ...

# %%
diabetes_dataset = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
diabetes_dataset.to_csv("diabetes_dataset.csv")
from google.colab import files

# %%
files.download('diabetes_dataset.csv')

# %% [markdown]
# **kMeans Clustering**

# %%
from pycaret.clustering import *
kMeanClusteringParameters = setup(diabetes_dataset)
# Out:
# <style type="text/css">
# #T_7c615_row4_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7c615" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c615_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_7c615_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c615_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c615_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_7c615_row0_col1" class="data row0 col1" >2653</td>
#     </tr>
#     <tr>
#       <th id="T_7c615_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7c615_row1_col0" class="data row1 col0" >Original data shape</td>
#       <td id="T_7c615_row1_col1" class="data row1 col1" >(768, 9)</td>
#     </tr>
#     <tr>
# ...

# %%
KMeanClusteringModel = create_model('kmeans', num_clusters=4)
# Out:
# <style type="text/css">
# </style>
# <table id="T_fc321" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fc321_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_fc321_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_fc321_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_fc321_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_fc321_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_fc321_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc321_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fc321_row0_col0" class="data row0 col0" >0.4288</td>
#       <td id="T_fc321_row0_col1" class="data row0 col1" >1120.5808</td>
# ...

# %%
kMeanPrediction = assign_model(KMeanClusteringModel)
kMeanPrediction
# Out:
#      Number of times pregnant  \
# 0                           6
# 1                           1
# 2                           8
# 3                           1
# 4                           0
# ..                        ...
# 763                        10
# 764                         2
# 765                         5
# 766                         1
# 767                         1
#
#      Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                  148
# 1                                                   85
# 2                                                  183
# 3                                                   89
# 4                                                  137
# ..                                                 ...
# 763                                                101
# 764                                                122
# 765                                                121
# ...

# %%
kMeanPrediction.to_csv("KMeanResult.csv")
print("Result file save sucessfully!!")
# Out:
# Result file save sucessfully!!

# %%
from google.colab import files
files.download('KMeanResult.csv')      # Uncomment this line
# Open and Explore result file (KMeanResult.csv).

# %%
x = save_model(KMeanClusteringModel, 'kMeanClusteringModelFile')
# Out:
# Transformation Pipeline and Model Successfully Saved

# %%
from google.colab import files
# files.download('kMeanClusteringModelFile.pkl')

# %% [markdown]
# **CLUSTERING**

# %%
newData = get_data("diabetes").iloc[:10]
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %%
newPredictions = predict_model(KMeanClusteringModel, data = newData)
newPredictions
# Out:
#    Number of times pregnant  \
# 0                       6.0
# 1                       1.0
# 2                       8.0
# 3                       1.0
# 4                       0.0
# 5                       5.0
# 6                       3.0
# 7                      10.0
# 8                       2.0
# 9                       8.0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                              148.0
# 1                                               85.0
# 2                                              183.0
# 3                                               89.0
# 4                                              137.0
# 5                                              116.0
# 6                                               78.0
# 7                                              115.0
# 8                                              197.0
# 9                                              125.0
#
# ...

# %% [markdown]
# **Evaluating Cluster Model**

# %%
evaluate_model(KMeanClusteringModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
# 2D plot
plot_model(KMeanClusteringModel, plot='cluster')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#3D plot
plot_model(KMeanClusteringModel, plot = 'tsne')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Elbow Plot
plot_model(KMeanClusteringModel, plot = 'elbow')

# %%
#Silhouette Plot
plot_model(KMeanClusteringModel, plot = 'silhouette')

# %%
# Distribution Plot
plot_model(KMeanClusteringModel, plot = 'distribution')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Clustering (KMean)**

# %%
# For Cluster = 3, 4, 5, 6
from pycaret.datasets import get_data
from pycaret.clustering import *

diabetes_dataset = get_data('diabetes', verbose=False)
setup(data = diabetes_dataset, verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_d6cfa" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6cfa_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d6cfa_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d6cfa_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d6cfa_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d6cfa_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d6cfa_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6cfa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6cfa_row0_col0" class="data row0 col0" >0.5104</td>
#       <td id="T_d6cfa_row0_col1" class="data row0 col1" >1142.5133</td>
# ...

# %%
import pandas as pd

# Create an empty list to store model summaries
model_summaries = []

# Iterate through different cluster numbers
for num_clusters in [3, 4, 5, 6]:
    print(f"For Cluster = {num_clusters}")

    # Create the KMeans model
    model = create_model('kmeans', num_clusters=num_clusters)

    # Get the model summary as a DataFrame
    model_summary = pull()

    # Create a new DataFrame with Cluster Number as the first column
    model_summary.insert(0, "Cluster Number", num_clusters)

    # Append the model summary to the list
    model_summaries.append(model_summary)

# Concatenate all model summaries into a single table
combined_table = pd.concat(model_summaries)

# Display the combined table
print(combined_table)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_e4d20" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e4d20_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_e4d20_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_e4d20_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_e4d20_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_e4d20_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_e4d20_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4d20_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e4d20_row0_col0" class="data row0 col0" >0.5104</td>
#       <td id="T_e4d20_row0_col1" class="data row0 col1" >1142.5133</td>
# ...

# %% [markdown]
# # ***Clustering: "Data Preprocessing"***

# %%
from pycaret.clustering import *
from pycaret.datasets import get_data

diabetes_dataset = get_data('diabetes')
# Out:
#    Number of times pregnant  \
# 0                         6
# 1                         1
# 2                         8
# 3                         1
# 4                         0
#
#    Plasma glucose concentration a 2 hours in an oral glucose tolerance test  \
# 0                                                148
# 1                                                 85
# 2                                                183
# 3                                                 89
# 4                                                137
#
#    Diastolic blood pressure (mm Hg)  Triceps skin fold thickness (mm)  \
# 0                                72                                35
# 1                                66                                29
# 2                                64                                 0
# 3                                66                                23
# 4                                40                                35
#
# ...

# %% [markdown]
# **Model Performance using "Normalization"**

# %%
#Model Performance using "Normalization"
#Elbow Plot
setup(data = diabetes_dataset, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')

#Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = diabetes_dataset, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d813b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d813b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d813b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d813b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d813b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d813b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d813b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d813b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d813b_row0_col0" class="data row0 col0" >0.1376</td>
#       <td id="T_d813b_row0_col1" class="data row0 col1" >130.9323</td>
# ...

# %%
#3D Plot for Cluster = 5
setup(data = diabetes_dataset, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('kmeans', num_clusters = 5)
plot_model(x, plot = 'tsne')
# Out:
# <style type="text/css">
# </style>
# <table id="T_58fa2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58fa2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_58fa2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_58fa2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_58fa2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_58fa2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_58fa2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58fa2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_58fa2_row0_col0" class="data row0 col0" >0.1961</td>
#       <td id="T_58fa2_row0_col1" class="data row0 col1" >126.4762</td>
# ...

# %% [markdown]
# # Model Performance using "Transformation"

# %%
# Model Performance using "Transformation"
#Elbow Plot
setup(data = diabetes_dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_7ef70" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ef70_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7ef70_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7ef70_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7ef70_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7ef70_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7ef70_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ef70_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ef70_row0_col0" class="data row0 col0" >0.4908</td>
#       <td id="T_7ef70_row0_col1" class="data row0 col1" >1500.4247</td>
# ...

# %%
# Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = diabetes_dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_976af" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_976af_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_976af_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_976af_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_976af_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_976af_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_976af_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_976af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_976af_row0_col0" class="data row0 col0" >0.5202</td>
#       <td id="T_976af_row0_col1" class="data row0 col1" >1152.6893</td>
# ...

# %% [markdown]
# # Model Performance using "PCA"

# %%
#Elbow Plot
setup(data = diabetes_dataset, pca = True, pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_d4560" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4560_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_d4560_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_d4560_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_d4560_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_d4560_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_d4560_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4560_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4560_row0_col0" class="data row0 col0" >0.4251</td>
#       <td id="T_d4560_row0_col1" class="data row0 col1" >1120.2916</td>
# ...

# %%
#Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = diabetes_dataset, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_7e2bb" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e2bb_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7e2bb_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7e2bb_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7e2bb_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7e2bb_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7e2bb_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e2bb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e2bb_row0_col0" class="data row0 col0" >0.5104</td>
#       <td id="T_7e2bb_row0_col1" class="data row0 col1" >1142.5133</td>
# ...

# %% [markdown]
# # Model Performance using "Transformation" + "Normalization"

# %%
#Model Performance using "Transformation" + "Normalization"
#Elbow Plot
setup(data = diabetes_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_7bf19" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7bf19_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7bf19_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7bf19_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7bf19_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7bf19_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7bf19_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bf19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7bf19_row0_col0" class="data row0 col0" >0.1743</td>
#       <td id="T_7bf19_row0_col1" class="data row0 col1" >141.1926</td>
# ...

# %%
setup(data = diabetes_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_17ee3" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17ee3_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_17ee3_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_17ee3_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_17ee3_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_17ee3_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_17ee3_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17ee3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17ee3_row0_col0" class="data row0 col0" >0.1825</td>
#       <td id="T_17ee3_row0_col1" class="data row0 col1" >160.8636</td>
# ...

# %% [markdown]
# # Model Performance using "Transformation" + "Normalization" + "PCA"

# %%
# Model Performance using "Transformation" + "Normalization" + "PCA"
#Elbow Plot
setup(data = diabetes_dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)
x = create_model('kmeans')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_27f14" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27f14_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_27f14_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_27f14_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_27f14_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_27f14_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_27f14_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27f14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_27f14_row0_col0" class="data row0 col0" >0.1739</td>
#       <td id="T_27f14_row0_col1" class="data row0 col1" >141.1900</td>
# ...

# %%
setup(data = diabetes_dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore',
      transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('kmeans', num_clusters = 3)

print("For Cluster = 4")
x = create_model('kmeans', num_clusters = 4)

print("For Cluster = 5")
x = create_model('kmeans', num_clusters = 5)

print("For Cluster = 6")
x = create_model('kmeans', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_ac11b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ac11b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ac11b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ac11b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ac11b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ac11b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ac11b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ac11b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ac11b_row0_col0" class="data row0 col0" >0.1825</td>
#       <td id="T_ac11b_row0_col1" class="data row0 col1" >160.8636</td>
# ...

# %% [markdown]
# # Other Clustering Techniques

# %% [markdown]
# **Hierarchical**

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

diabetesDataSet = get_data('diabetes', verbose=False)
setup(data = diabetesDataSet, verbose=False)

x = create_model('hclust')
plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_b6f1b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b6f1b_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_b6f1b_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_b6f1b_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_b6f1b_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_b6f1b_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_b6f1b_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b6f1b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b6f1b_row0_col0" class="data row0 col0" >0.3903</td>
#       <td id="T_b6f1b_row0_col1" class="data row0 col1" >1015.4862</td>
# ...

# %%
hierarchicalModel = create_model('hclust', num_clusters=4)
hierarchicalModelPrediction = assign_model(hierarchicalModel)
hierarchicalModelPrediction
# Out:
# <style type="text/css">
# </style>
# <table id="T_00046" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00046_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_00046_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_00046_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_00046_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_00046_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_00046_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00046_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00046_row0_col0" class="data row0 col0" >0.3903</td>
#       <td id="T_00046_row0_col1" class="data row0 col1" >1015.4862</td>
# ...

# %%
evaluate_model(hierarchicalModel)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

diabetesDataSet = get_data('diabetes', verbose=False)
setup(data = diabetesDataSet, verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_67265" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_67265_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_67265_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_67265_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_67265_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_67265_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_67265_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_67265_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_67265_row0_col0" class="data row0 col0" >0.5282</td>
#       <td id="T_67265_row0_col1" class="data row0 col1" >950.1220</td>
# ...

# %% [markdown]
# # Normalization

# %%
#Model Performance using "Normalization"
#Elbow Plot
setup(data = diabetes_dataset, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')

#Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = diabetes_dataset, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7b690" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7b690_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_7b690_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_7b690_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_7b690_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_7b690_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_7b690_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b690_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7b690_row0_col0" class="data row0 col0" >0.1454</td>
#       <td id="T_7b690_row0_col1" class="data row0 col1" >113.1997</td>
# ...

# %% [markdown]
# # Transformation

# %%
# Model Performance using "Transformation"
#Elbow Plot
setup(data = diabetes_dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')

# Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = diabetes_dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_76df2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_76df2_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_76df2_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_76df2_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_76df2_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_76df2_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_76df2_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76df2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_76df2_row0_col0" class="data row0 col0" >0.4652</td>
#       <td id="T_76df2_row0_col1" class="data row0 col1" >1400.8822</td>
# ...

# %% [markdown]
# # PCA

# %%
#Elbow Plot
setup(data = diabetes_dataset, pca = True, pca_method = 'linear', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')

#Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = diabetes_dataset, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3c037" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c037_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3c037_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3c037_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3c037_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3c037_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3c037_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c037_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c037_row0_col0" class="data row0 col0" >0.3903</td>
#       <td id="T_3c037_row0_col1" class="data row0 col1" >1015.4862</td>
# ...

# %% [markdown]
# # Transformation" + "Normalization

# %%
#Model Performance using "Transformation" + "Normalization"
#Elbow Plot
setup(data = diabetes_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('hclust')
plot_model(x, plot = 'elbow')

setup(data = diabetes_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
x = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
x = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
x = create_model('hclust', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3add9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3add9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_3add9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_3add9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_3add9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_3add9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_3add9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3add9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3add9_row0_col0" class="data row0 col0" >0.1573</td>
#       <td id="T_3add9_row0_col1" class="data row0 col1" >120.3279</td>
# ...

# %% [markdown]
# # "Transformation" + "Normalization" + "PCA"

# %%
# Model Performance using "Transformation" + "Normalization" + "PCA"
#Elbow Plot

setup(data =diabetes_dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

x = create_model('hclust')
plot_model(x, plot = 'elbow')

setup(data = diabetes_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('hclust', num_clusters = 3)

print("For Cluster = 4")
y = create_model('hclust', num_clusters = 4)

print("For Cluster = 5")
z = create_model('hclust', num_clusters = 5)

print("For Cluster = 6")
w = create_model('hclust', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_6b967" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6b967_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_6b967_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_6b967_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_6b967_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_6b967_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_6b967_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b967_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6b967_row0_col0" class="data row0 col0" >0.1573</td>
#       <td id="T_6b967_row0_col1" class="data row0 col1" >120.3279</td>
# ...

# %% [markdown]
# # Mean shift clustering              'meanshift'

# %%
from pycaret.datasets import get_data
from pycaret.clustering import *

diabetesDataSet = get_data('diabetes', verbose=False)
setup(data = diabetesDataSet, verbose=False)

x = create_model('meanshift')
# plot_model(x, plot = 'elbow')
# Out:
# <style type="text/css">
# </style>
# <table id="T_58e77" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_58e77_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_58e77_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_58e77_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_58e77_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_58e77_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_58e77_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58e77_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_58e77_row0_col0" class="data row0 col0" >0.6046</td>
#       <td id="T_58e77_row0_col1" class="data row0 col1" >331.7479</td>
# ...

# %%
print("For Cluster = 3")
x = create_model('dbscan', num_clusters = 3)

print("For Cluster = 4")
x = create_model('dbscan', num_clusters = 4)

print("For Cluster = 5")
x = create_model('dbscan', num_clusters = 5)

print("For Cluster = 6")
x = create_model('dbscan', num_clusters = 6)
# Out:
# For Cluster = 3
# <style type="text/css">
# </style>
# <table id="T_585c4" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_585c4_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_585c4_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_585c4_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_585c4_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_585c4_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_585c4_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_585c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_585c4_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_585c4_row0_col1" class="data row0 col1" >0</td>
# ...

# %%
#Model Performance using "Normalization"
#Elbow Plot
setup(data = diabetes_dataset, normalize = True, normalize_method = 'zscore', verbose=False)
x = create_model('dbscan')
# plot_model(x, plot = 'elbow')

#Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = diabetes_dataset, normalize = True, normalize_method = 'zscore', verbose=False)

print("For Cluster = 3")
x = create_model('dbscan', num_clusters = 3)

print("For Cluster = 4")
x = create_model('dbscan', num_clusters = 4)

print("For Cluster = 5")
x = create_model('dbscan', num_clusters = 5)

print("For Cluster = 6")
x = create_model('dbscan', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_0dc27" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0dc27_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_0dc27_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_0dc27_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_0dc27_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_0dc27_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_0dc27_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0dc27_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0dc27_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_0dc27_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_0dc27_row0_col2" class="data row0 col2" >0</td>
# ...

# %%
# Model Performance using "Transformation"
#Elbow Plot
setup(data = diabetes_dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)
x = create_model('dbscan')
# plot_model(x, plot = 'elbow')

# Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = diabetes_dataset, transformation = True, transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('dbscan', num_clusters = 3)

print("For Cluster = 4")
x = create_model('dbscan', num_clusters = 4)

print("For Cluster = 5")
x = create_model('dbscan', num_clusters = 5)

print("For Cluster = 6")
x = create_model('dbscan', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5f5c8" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5f5c8_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_5f5c8_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_5f5c8_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_5f5c8_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_5f5c8_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_5f5c8_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5f5c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5f5c8_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_5f5c8_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_5f5c8_row0_col2" class="data row0 col2" >0</td>
# ...

# %%
#PCA
#Elbow Plot
setup(data = diabetes_dataset, pca = True, pca_method = 'linear', verbose=False)
x = create_model('dbscan')
# plot_model(x, plot = 'elbow')

#Evaluation parameters for Cluster = 3, 4, 5, 6
setup(data = diabetes_dataset, pca = True, pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('dbscan', num_clusters = 3)

print("For Cluster = 4")
x = create_model('dbscan', num_clusters = 4)

print("For Cluster = 5")
x = create_model('dbscan', num_clusters = 5)

print("For Cluster = 6")
x = create_model('dbscan', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ea5e9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ea5e9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_ea5e9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_ea5e9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_ea5e9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_ea5e9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_ea5e9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ea5e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ea5e9_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ea5e9_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_ea5e9_row0_col2" class="data row0 col2" >0</td>
# ...

# %%
#Model Performance using "Transformation" + "Normalization"
#Elbow Plot
setup(data = diabetes_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)
x = create_model('dbscan')


setup(data = diabetes_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', verbose=False)

print("For Cluster = 3")
x = create_model('dbscan', num_clusters = 3)

print("For Cluster = 4")
x = create_model('dbscan', num_clusters = 4)

print("For Cluster = 5")
x = create_model('dbscan', num_clusters = 5)

print("For Cluster = 6")
x = create_model('dbscan', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_145cd" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_145cd_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_145cd_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_145cd_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_145cd_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_145cd_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_145cd_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_145cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_145cd_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_145cd_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_145cd_row0_col2" class="data row0 col2" >0</td>
# ...

# %%
# Model Performance using "Transformation" + "Normalization" + "PCA"
#Elbow Plot

setup(data = diabetes_dataset, transformation = True, normalize = True, pca = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson',
      pca_method = 'linear', verbose=False)

x = create_model('dbscan')
# plot_model(x, plot = 'elbow')

setup(data = diabetes_dataset, transformation = True, normalize = True,
      normalize_method = 'zscore', transformation_method = 'yeo-johnson', pca_method = 'linear', verbose=False)

print("For Cluster = 3")
x = create_model('dbscan', num_clusters = 3)

print("For Cluster = 4")
y = create_model('dbscan', num_clusters = 4)

print("For Cluster = 5")
z = create_model('dbscan', num_clusters = 5)

print("For Cluster = 6")
w = create_model('dbscan', num_clusters = 6)
# Out:
# <style type="text/css">
# </style>
# <table id="T_c5eb9" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5eb9_level0_col0" class="col_heading level0 col0" >Silhouette</th>
#       <th id="T_c5eb9_level0_col1" class="col_heading level0 col1" >Calinski-Harabasz</th>
#       <th id="T_c5eb9_level0_col2" class="col_heading level0 col2" >Davies-Bouldin</th>
#       <th id="T_c5eb9_level0_col3" class="col_heading level0 col3" >Homogeneity</th>
#       <th id="T_c5eb9_level0_col4" class="col_heading level0 col4" >Rand Index</th>
#       <th id="T_c5eb9_level0_col5" class="col_heading level0 col5" >Completeness</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5eb9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c5eb9_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c5eb9_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_c5eb9_row0_col2" class="data row0 col2" >0</td>
# ...
